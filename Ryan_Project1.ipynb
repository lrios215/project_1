# %%
# %matplotlib notebook

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# %%
# Study data files
Atl_2019_crime = "./Resources/2019_CrimeData_ATL.csv"
Atl_2020_crime = "./Resources/2020_Crime_Data_ATL.csv"
covid_data = "./Resources/Georgia_COVID-19 EDITED.csv"
unemployment = "./Resources/GAUR.csv"

# %%
crime_may2019 = pd.read_csv(Atl_2019_crime)
crime_may2019.head()
# Out:
#    UC2_Literal  Report Number Report Date                     Location  Beat  \
# 0      ROBBERY      191510360   5/31/2019          472 COURTLAND ST NE   509
# 1      ROBBERY      191511609   5/31/2019  2423 MARTIN L KING JR DR NW   108
# 2      ROBBERY      191511411   5/31/2019             1342 PRYOR RD SW   305
# 3  AGG ASSAULT      191510268   5/31/2019         151 CLEVELAND AVE SW   310
# 4  AGG ASSAULT      191511544   5/31/2019           1083 EUCLID AVE NE   602
#
#         Neigborhood NPU       Lat      Long
# 0          Downtown   M  33.76763 -84.38419
# 1   Florida Heights   I  33.75183 -84.46623
# 2        High Point   Y  33.71850 -84.39341
# 3  Browns Mill Park   Z  33.68148 -84.39422
# 4        Inman Park   N  33.76323 -84.35155

# %%
unemployment_2020_df = pd.read_csv(unemployment)
unemployment_2020_df
# Out:
#        DATE     %
# 0    1/1/19   3.8
# 1    2/1/19   3.7
# 2    3/1/19   3.7
# 3    4/1/19   3.6
# 4    5/1/19   3.6
# 5    6/1/19   3.5
# 6    7/1/19   3.4
# 7    8/1/19   3.3
# 8    9/1/19   3.2
# 9   10/1/19   3.2
# 10  11/1/19   3.1
# 11  12/1/19   3.1
# 12   1/1/20   3.1
# 13   2/1/20   3.1
# 14   3/1/20   4.6
# 15   4/1/20  12.6
# 16   5/1/20   9.4
# 17   6/1/20   7.6
# 18   7/1/20   7.6
# 19   8/1/20   5.7
# 20   9/1/20   6.4

# %%
covid_df = pd.read_csv(covid_data)
covid_df
# Out:
#                      COUNTY DATE STAMP  FEMALE  MALE  SEX UNKNOWN  SUM CASES
# 0      NON-GEORGIA RESIDENT  4/16/2020     220   222           69        511
# 1      NON-GEORGIA RESIDENT  4/17/2020     233   242           72        547
# 2      NON-GEORGIA RESIDENT  4/18/2020     237   246           77        560
# 3      NON-GEORGIA RESIDENT  4/19/2020     245   253           83        581
# 4      NON-GEORGIA RESIDENT  4/20/2020     254   261           91        606
# ...                     ...        ...     ...   ...          ...        ...
# 47613                WALKER   9/1/2020     615   602           22       1239
# 47614                WALKER   9/2/2020     630   610           22       1262
# 47615                WALKER   9/3/2020     646   618           22       1286
# 47616                WALKER   9/4/2020     655   629           23       1307
# 47617                WALKER   9/5/2020     659   633           23       1315
#
# [47618 rows x 6 columns]

# %%
covid_count_county_df = covid_df.loc[covid_df['COUNTY'] == 'FULTON']
#covid_count_county_df = covid_df(['FULTON'])
covid_count_county_df['DATE STAMP'] = pd.to_datetime(covid_count_county_df['DATE STAMP'])
covid_count_county_df
# Out:
# <ipython-input-65-ff5ada6e3608>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covid_count_county_df['DATE STAMP'] = pd.to_datetime(covid_count_county_df['DATE STAMP'])
#       COUNTY DATE STAMP  FEMALE   MALE  SEX UNKNOWN  SUM CASES
# 3812  FULTON 2020-01-01       0      0            0          0
# 3813  FULTON 2020-01-02       0      0            0          0
# 3814  FULTON 2020-01-03       0      0            0          0
# 3815  FULTON 2020-01-04       0      0            0          0
# 3816  FULTON 2020-01-05       0      0            0          0
# ...      ...        ...     ...    ...          ...        ...
# 4102  FULTON 2020-10-16   15219  13882          844      29945
# 4103  FULTON 2020-10-17   15235  13904          845      29984
# 4104  FULTON 2020-10-18   15241  13907          845      29993
# 4105  FULTON 2020-10-19   15242  13907          845      29994
# 4106  FULTON 2020-10-20   15243  13907          846      29996
#
# [294 rows x 6 columns]

# %%
plt.plot(covid_count_county_df['DATE STAMP'], covid_count_county_df['SUM CASES'])
plt.xlabel("DATE")
plt.ylabel("COVID CASES")
plt.title("COVID in FULTON COUNTY")
plt.xticks(rotation=45)
plt.show()
plt.savefig("C:\\Users\\ryoun\\OneDrive\\Desktop\\project_1\\Images\\Covid Line Chart.png")
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
plt.plot(unemployment_2020_df['DATE'], unemployment_2020_df['%'])
plt.xlabel("DATE")
plt.ylabel("% Unemployment")
plt.xlim(0,20)
plt.ylim(0, 15)
plt.title("Unemployment")
plt.show()
plt.savefig("C:\\Users\\ryoun\\OneDrive\\Desktop\\project_1\\Images\\Unemployment Line Chart.png")
